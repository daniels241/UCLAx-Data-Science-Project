# %%
## Imports
import pandas as pd
import numpy as np 
import datadotworld as dw
import matplotlib.pyplot as plot
import seaborn as sns
from pathlib import Path
import sys
import os

# %% [markdown]
# # Data DOE - _Dept of Education Homeless Student Counts_
#    - 6 Dataframes:
#     - doe_homeless_students_coc_agg
#     - coc_code_leaid_crosswalk
#     - ed_homeless_students
#     - edyouthcount
#     - rhy_grantees
#     - ed_homeless_students_all_years

# %%
## Download data with DataDotWorld package
#master_data  = dw.load_dataset('mschnars/us-homelessness-master-data')

# %%
## Change Data Path in order to Read in data from local CSVs
os.chdir(str(Path(os.getcwd()).parent / 'Data'))

# %% [markdown]
# ## doe_homeless_students_coc_agg

# %%
#doe_homeless_students_coc_agg = master_data.dataframes['doe_homeless_students_coc_agg']
doe_homeless_students_coc_agg = pd.read_csv('doe_homeless_students_coc_agg.csv')
doe_homeless_students_coc_agg.head(20)
# Out:
#     year coc_number  doe_total_count  doe_unsheltered  doe_sheltered  \
# 0   2016     AK-500             2905              155            819
# 1   2014     AK-500             2155              137            512
# 2   2015     AK-500             2217               91            551
# 3   2017     AK-500             2476              168            454
# 4   2014     AK-501             1772              221            388
# 5   2015     AK-501             1890              232            474
# 6   2016     AK-501             2127              265            490
# 7   2017     AK-501             1642              240            272
# 8   2015     AL-500             2907               13            152
# 9   2017     AL-500             2042               21             90
# 10  2014     AL-500             2758               16            208
# 11  2016     AL-500             2050                3             56
# 12  2015     AL-501             6392               55            471
# ...

# %% [markdown]
# ## coc_code_leaid_crosswalk

# %%
#coc_code_leaid_crosswalk = master_data.dataframes['coc_code_leaid_crosswalk']
coc_code_leaid_crosswalk = pd.read_csv('coc_code_leaid_crosswalk.csv')
coc_code_leaid_crosswalk.head(20)
# Out:
#    coc_number                                          coc_name  year
# 0      AL-507                          Alabama Balance of State  2017
# 1      AK-500                                         Anchorage  2017
# 2      AL-500  Birmingham/Jefferson, St. Clair, Shelby Counties  2017
# 3      AL-503                          Huntsville/North Alabama  2017
# 4      AK-501                           Alaska Balance of State  2017
# 5      AL-505                         Gadsden/Northeast Alabama  2017
# 6      AL-501               Mobile City & County/Baldwin County  2017
# 7      AL-504                          Montgomery City & County  2017
# 8      AL-502                        Florence/Northwest Alabama  2017
# 9      AL-506                          Tuscaloosa City & County  2017
# 10     AZ-502                     Phoenix, Mesa/Maricopa County  2017
# 11     AZ-500                          Arizona Balance of State  2017
# ...

# %% [markdown]
# ## ed_homeless_students

# %%
#ed_homeless_students = master_data.dataframes['ed_homeless_students']
ed_homeless_students  = pd.read_csv('ed_homeless_students.csv')
ed_homeless_students.head(20)
# Out:
# C:\Users\danny\AppData\Local\anaconda3\envs\dev\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     local_education_agency_identifier school_year state_name  state_fips  \
# 0                              100005   2016-2017    Alabama           1
# 1                              100006   2016-2017    Alabama           1
# 2                              200180   2016-2017     Alaska           2
# 3                              100007   2016-2017    Alabama           1
# 4                              200800   2016-2017     Alaska           2
# 5                              100008   2016-2017    Alabama           1
# 6                              200001   2016-2017     Alaska           2
# 7                              100011   2016-2017    Alabama           1
# ...

# %% [markdown]
# ## edyouthcount

# %%
#edyouthcount = master_data.dataframes['edyouthcount']
edyouthcount = pd.read_csv('edyouthcount.csv')
edyouthcount.head(20)
# Out:
#     cocnumber  of_leas_in_coc  total_hcy_count  hotels_motels  unsheltered  \
# 0   Unmatched             271          38112.0         3190.0        860.0
# 1      AK-500               2           2476.0          166.0        168.0
# 2      AK-501              20           1642.0           63.0        240.0
# 3      AL-500              14           1938.0          134.0         21.0
# 4      AL-501               5           6159.0          156.0         63.0
# 5      AL-502              11            875.0           11.0         33.0
# 6      AL-503               8            726.0          102.0         15.0
# 7      AL-504               6           1216.0           80.0         16.0
# 8      AL-506               2            432.0           53.0          NaN
# 9      AL-507              57           2731.0           93.0        133.0
# 10     AR-500              23           2076.0           77.0          8.0
# ...

# %% [markdown]
# ## rhy_grantees

# %%
#rhy_grantees = master_data.dataframes['rhy_grantees']
rhy_grantees = pd.read_csv('rhy_grantees.csv')
rhy_grantees.head(20)
# Out:
#    coc_number                                           coc_name coc_state  \
# 0      AK-500                                      Anchorage CoC        AK
# 1      AK-500                                      Anchorage CoC        AK
# 2      AK-501                        Alaska Balance of State CoC        AK
# 3      AK-501                        Alaska Balance of State CoC        AK
# 4      AK-501                        Alaska Balance of State CoC        AK
# 5      AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...        AL
# 6      AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...        AL
# 7      AL-503                       Huntsville/North Alabama CoC        AL
# 8      AL-503                       Huntsville/North Alabama CoC        AL
# 9      AL-507                       Alabama Balance of State CoC        AL
# 10     AR-500                   Little Rock/Central Arkansas CoC        AR
# ...

# %% [markdown]
# ## ed_homeless_students_all_years

# %%
#ed_homeless_students_all_years = master_data.dataframes['ed_homeless_students_all_years']
ed_homeless_students_all_years = pd.read_csv('ed_homeless_students_all_years.csv')
ed_homeless_students_all_years.head(20)
# Out:
#     local_education_agency_identifier school_year state_name  state_fips  \
# 0                              100005   2016-2017    Alabama           1
# 1                              100006   2016-2017    Alabama           1
# 2                              100007   2016-2017    Alabama           1
# 3                              100008   2016-2017    Alabama           1
# 4                              100011   2016-2017    Alabama           1
# 5                              100012   2016-2017    Alabama           1
# 6                              100013   2016-2017    Alabama           1
# 7                              100030   2016-2017    Alabama           1
# 8                              100060   2016-2017    Alabama           1
# 9                              100090   2016-2017    Alabama           1
# 10                             100100   2016-2017    Alabama           1
# 11                             100120   2016-2017    Alabama           1
# ...

# %% [markdown]
# #  Data PIT _Point in Time Count Data_
#    - 3 Dataframes
#     - pit_all
#     - pit_coc_codes
#     - pit_coc_categories

# %% [markdown]
# ## pit_all

# %%
#pit_all = master_data.dataframes['pit_all']
pit_all = pd.read_csv('pit_all.csv')
pit_all.head(20)
# Out:
#     year coc_number                                           coc_name  \
# 0   2007     AK-500                                      Anchorage CoC
# 1   2008     AK-500                                      Anchorage CoC
# 2   2007     AK-501                        Alaska Balance of State CoC
# 3   2008     AK-501                        Alaska Balance of State CoC
# 4   2007     AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 5   2008     AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 6   2007     AL-501            Mobile City & County/Baldwin County CoC
# 7   2008     AL-501            Mobile City & County/Baldwin County CoC
# 8   2007     AL-502                     Florence/Northwest Alabama CoC
# 9   2007     AL-503                       Huntsville/North Alabama CoC
# 10  2007     AL-504                       Montgomery City & County CoC
# 11  2007     AL-505                      Gadsden/Northeast Alabama CoC
# ...

# %% [markdown]
# ## pit_coc_codes

# %%
#pit_coc_codes = master_data.dataframes['pit_coc_codes']
pit_coc_codes = pd.read_csv('pit_coc_codes.csv')
pit_coc_codes.head(20)
# Out:
#     year coc_number                                          coc_name
# 0   2007     AK-500                                         Anchorage
# 1   2007     AK-501                           Alaska Balance of State
# 2   2007     AL-500  Birmingham,Jefferson, St. Clair, Shelby Counties
# 3   2007     AL-501               Mobile City & County,Baldwin County
# 4   2007     AL-502                        Florence,Northwest Alabama
# 5   2007     AL-503                          Huntsville,North Alabama
# 6   2007     AL-504                          Montgomery City & County
# 7   2007     AL-505                         Gadsden,Northeast Alabama
# 8   2007     AL-506                          Tuscaloosa City & County
# 9   2007     AL-507                          Alabama Balance of State
# 10  2007     AR-500                      Little Rock,Central Arkansas
# 11  2007     AR-501                   Fayetteville,Northwest Arkansas
# ...

# %% [markdown]
# ## pit_coc_categories

# %%
#pit_coc_categories = master_data.dataframes['pit_coc_categories']
pit_coc_categories = pd.read_csv('pit_coc_categories.csv')
pit_coc_categories.head(20)
# Out:
#    coc_number      coc_category
# 0      AK-500  Other Urban CoCs
# 1      AK-501        Rural CoCs
# 2      AL-500     Suburban CoCs
# 3      AL-501  Other Urban CoCs
# 4      AL-502        Rural CoCs
# 5      AL-503  Other Urban CoCs
# 6      AL-504  Other Urban CoCs
# 7      AL-505        Rural CoCs
# 8      AL-506  Other Urban CoCs
# 9      AL-507        Rural CoCs
# 10     AR-500  Other Urban CoCs
# 11     AR-501  Other Urban CoCs
# 12     AR-503        Rural CoCs
# 13     AR-504        Rural CoCs
# 14     AR-505        Rural CoCs
# 15     AR-508        Rural CoCs
# 16     AZ-500        Rural CoCs
# 17     AZ-501      Major Cities
# 18     AZ-502      Major Cities
# 19     CA-500      Major Cities

# %% [markdown]
# # Data Cen _Population Estimates and Projections_
#   - 5 DataFrames
#       - lu_county_coc_bos_region
#       - coc_sensus_population
#       - crosswalk
#       - country_pop_w_coc_code
#       - county_population

# %% [markdown]
# ## lu_county_coc_bos_region

# %%
lu_county_coc_bos_region = pd.read_csv('lu_county_coc_bos_region.csv')
lu_county_coc_bos_region.head(20)
# Out:
#    state_postal_code       county_name  county_fips_code coc_number bos_region
# 0                 AL    Autauga County              1001        NaN        NaN
# 1                 AL    Baldwin County              1003        NaN        NaN
# 2                 AL    Barbour County              1005        NaN        NaN
# 3                 AL       Bibb County              1007        NaN        NaN
# 4                 AL     Blount County              1009        NaN        NaN
# 5                 AL    Bullock County              1011        NaN        NaN
# 6                 AL     Butler County              1013        NaN        NaN
# 7                 AL    Calhoun County              1015        NaN        NaN
# 8                 AL   Chambers County              1017        NaN        NaN
# 9                 AL   Cherokee County              1019        NaN        NaN
# 10                AL    Chilton County              1021        NaN        NaN
# ...

# %% [markdown]
# ## coc_sensus_population

# %%
coc_census_population = pd.read_csv('coc_census_population.csv')
coc_census_population.head(20)
# Out:
#     year coc_number  cen_population_estimate  cen_population_density
# 0   2010     AZ-500                  1600930               20.005635
# 1   2011     AZ-500                  1610025               20.131228
# 2   2012     AZ-500                  1615189               20.169769
# 3   2013     AZ-500                  1618543               20.192560
# 4   2014     AZ-500                  1633657               20.384847
# 5   2015     AZ-500                  1648810               20.570183
# 6   2016     AZ-500                  1669225               20.811003
# 7   2017     AZ-500                  1691794               21.096359
# 8   2018     AZ-500                  1721749               21.450323
# 9   2010     AZ-502                  3825191              415.815486
# 10  2011     AZ-502                  3875065              421.237015
# 11  2012     AZ-502                  3948225              429.189836
# 12  2013     AZ-502                  4019019              436.885463
# ...

# %% [markdown]
# ## crosswalk

# %%
crosswalk = pd.read_csv('crosswalk.csv')
crosswalk.head(20)
# Out:
#    state_postal_code     county_name  county_fips_code  year  \
# 0                 AL  Autauga County              1001  2010
# 1                 AL  Autauga County              1001  2011
# 2                 AL  Autauga County              1001  2012
# 3                 AL  Autauga County              1001  2013
# 4                 AL  Autauga County              1001  2014
# 5                 AL  Autauga County              1001  2015
# 6                 AL  Autauga County              1001  2016
# 7                 AL  Autauga County              1001  2017
# 8                 AL  Autauga County              1001  2018
# 9                 AL  Baldwin County              1003  2010
# 10                AL  Baldwin County              1003  2011
# 11                AL  Baldwin County              1003  2012
# 12                AL  Baldwin County              1003  2013
# 13                AL  Baldwin County              1003  2014
# ...

# %% [markdown]
# ## county_pop_w_coc_code

# %%
county_pop_w_coc_code = pd.read_csv('county_pop_w_coc_code.csv')
county_pop_w_coc_code.head(20)
# Out:
#    state_postal_code     county_name  county_fips_code  year  \
# 0                 AL  Autauga County              1001  2010
# 1                 AL  Autauga County              1001  2011
# 2                 AL  Autauga County              1001  2012
# 3                 AL  Autauga County              1001  2013
# 4                 AL  Autauga County              1001  2014
# 5                 AL  Autauga County              1001  2015
# 6                 AL  Autauga County              1001  2016
# 7                 AL  Autauga County              1001  2017
# 8                 AL  Autauga County              1001  2018
# 9                 AL  Baldwin County              1003  2010
# 10                AL  Baldwin County              1003  2011
# 11                AL  Baldwin County              1003  2012
# 12                AL  Baldwin County              1003  2013
# 13                AL  Baldwin County              1003  2014
# ...

# %% [markdown]
# ## county_population

# %%
county_population = pd.read_csv('county_population.csv')
county_population.head(20)
# Out:
#    state_postal_code     county_name  county_fips_code  year  \
# 0                 AL  Autauga County              1001  2010
# 1                 AL  Autauga County              1001  2011
# 2                 AL  Autauga County              1001  2012
# 3                 AL  Autauga County              1001  2013
# 4                 AL  Autauga County              1001  2014
# 5                 AL  Autauga County              1001  2015
# 6                 AL  Autauga County              1001  2016
# 7                 AL  Autauga County              1001  2017
# 8                 AL  Autauga County              1001  2018
# 9                 AL  Baldwin County              1003  2010
# 10                AL  Baldwin County              1003  2011
# 11                AL  Baldwin County              1003  2012
# 12                AL  Baldwin County              1003  2013
# 13                AL  Baldwin County              1003  2014
# ...

# %% [markdown]
# # Data ARD _CoC Annual Renewal Demand (ARD) & Preliminary Pro Rata Need (PPRN)_
#   - 4 DataFrames
#       - ard_coc_codes
#       - ard_full
#       - ard_aggregates
#       - ard_all_years

# %% [markdown]
# ## ard_coc_codes

# %%
ard_coc_codes = pd.read_csv('ard_coc_codes.csv')
ard_coc_codes.head(20)
# Out:
#     year coc_number                                          coc_name
# 0   2012     AK-500                                         Anchorage
# 1   2013     AK-500                                         Anchorage
# 2   2014     AK-500                                         Anchorage
# 3   2015     AK-500                                         Anchorage
# 4   2016     AK-500                                         Anchorage
# 5   2017     AK-500                                         Anchorage
# 6   2018     AK-500                                         Anchorage
# 7   2019     AK-500                                         Anchorage
# 8   2012     AK-501                           Alaska Balance of State
# 9   2013     AK-501                           Alaska Balance of State
# 10  2014     AK-501                           Alaska Balance of State
# 11  2015     AK-501                           Alaska Balance of State
# ...

# %% [markdown]
# ## ard_full

# %%
ard_full = pd.read_csv('ard_full.csv')
ard_full.head(20)
# Out:
#     year coc_number                                coc_number_and_name  \
# 0   2019     AK-500                                   AK-500-ANCHORAGE
# 1   2019     AK-501                     AK-501-ALASKA BALANCE OF STATE
# 2   2019     AL-500  AL-500-BIRMINGHAM,JEFFERSON,ST.CLAIR,SHELBY CO...
# 3   2019     AL-501         AL-501-MOBILE CITY & COUNTY,BALDWIN COUNTY
# 4   2019     AL-502                  AL-502-FLORENCE,NORTHWEST ALABAMA
# 5   2019     AL-503                    AL-503-HUNTSVILLE,NORTH ALABAMA
# 6   2019     AL-504                    AL-504-MONTGOMERY CITY & COUNTY
# 7   2019     AL-506                    AL-506-TUSCALOOSA CITY & COUNTY
# 8   2019     AL-507                    AL-507-ALABAMA BALANCE OF STATE
# 9   2019     AR-500                AR-500-LITTLE ROCK,CENTRAL ARKANSAS
# 10  2019     AR-501             AR-501-FAYETTEVILLE,NORTHWEST ARKANSAS
# 11  2019     AR-503                   AR-503-ARKANSAS BALANCE OF STATE
# ...

# %% [markdown]
# ## ard_aggregates

# %%
ard_aggregates = pd.read_csv('ard_aggregates.csv')
ard_aggregates.head(20)
# Out:
#    coc_number  year  ard_ard  ard_pprn
# 0      AK-500  2015  2824705   1138309
# 1      AK-500  2016  2891188   1169576
# 2      AK-500  2017  2849941   1210110
# 3      AK-500  2018  2847097   1293735
# 4      AK-500  2019  3784364   1264986
# 5      AK-501  2015   807072    602107
# 6      AK-501  2016   738551    669635
# 7      AK-501  2017   738301    707296
# 8      AK-501  2018   776502    756772
# 9      AK-501  2019   790036    792338
# 10     AL-500  2015  8319846   5389558
# 11     AL-500  2016  8748112   5708402
# 12     AL-500  2017  8647184   6079332
# 13     AL-500  2018  9109238   6505662
# 14     AL-500  2019  9223098   6587951
# 15     AL-501  2015  3837513   2837441
# 16     AL-501  2016  3838133   2980527
# 17     AL-501  2017  3736133   3048353
# 18     AL-501  2018  3741586   3230092
# 19     AL-501  2019  3699553   3110886

# %% [markdown]
# ## ard_all_years

# %%
ard_all_years = pd.read_csv('ard_all_years.csv')
ard_all_years.head(20)
# Out:
#    coc_number                                          coc_name  year  \
# 0      AK-500                                         Anchorage  2012
# 1      AK-500                                         Anchorage  2013
# 2      AK-500                                         Anchorage  2014
# 3      AK-500                                         Anchorage  2015
# 4      AK-500                                         Anchorage  2016
# 5      AK-500                                         Anchorage  2017
# 6      AK-500                                         Anchorage  2018
# 7      AK-500                                         Anchorage  2019
# 8      AK-501                           Alaska Balance of State  2012
# 9      AK-501                           Alaska Balance of State  2013
# 10     AK-501                           Alaska Balance of State  2014
# 11     AK-501                           Alaska Balance of State  2015
# ...

# %%
## Imports
import pandas as pd
import numpy as np 
import datadotworld as dw
import matplotlib.pyplot as plot
import seaborn as sns
from pathlib import Path
import sys
import os

# %% [markdown]
# # Data DOE - _Dept of Education Homeless Student Counts_
#    - 6 Dataframes:
#     - doe_homeless_students_coc_agg
#     - coc_code_leaid_crosswalk
#     - ed_homeless_students
#     - edyouthcount
#     - rhy_grantees
#     - ed_homeless_students_all_years

# %%
## Download data with DataDotWorld package
#master_data  = dw.load_dataset('mschnars/us-homelessness-master-data')

# %%
## Add Data Path in order to Read in data from local CSVs
sys.path.insert(1, str(Path(os.getcwd()).parent / 'Data'))

# %% [markdown]
# ## doe_homeless_students_coc_agg

# %%
#doe_homeless_students_coc_agg = master_data.dataframes['doe_homeless_students_coc_agg']
doe_homeless_students_coc_agg = 
doe_homeless_students_coc_agg.head(20)
# Out:
#     year coc_number  doe_total_count  doe_unsheltered  doe_sheltered  \
# 0   2016     AK-500             2905              155            819
# 1   2014     AK-500             2155              137            512
# 2   2015     AK-500             2217               91            551
# 3   2017     AK-500             2476              168            454
# 4   2014     AK-501             1772              221            388
# 5   2015     AK-501             1890              232            474
# 6   2016     AK-501             2127              265            490
# 7   2017     AK-501             1642              240            272
# 8   2015     AL-500             2907               13            152
# 9   2017     AL-500             2042               21             90
# 10  2014     AL-500             2758               16            208
# 11  2016     AL-500             2050                3             56
# 12  2015     AL-501             6392               55            471
# ...

# %% [markdown]
# ## coc_code_leaid_crosswalk

# %%
coc_code_leaid_crosswalk = master_data.dataframes['coc_code_leaid_crosswalk']
coc_code_leaid_crosswalk.head(20)
# Out:
#    coc_number                                          coc_name  year
# 0      AL-507                          Alabama Balance of State  2017
# 1      AK-500                                         Anchorage  2017
# 2      AL-500  Birmingham/Jefferson, St. Clair, Shelby Counties  2017
# 3      AL-503                          Huntsville/North Alabama  2017
# 4      AK-501                           Alaska Balance of State  2017
# 5      AL-505                         Gadsden/Northeast Alabama  2017
# 6      AL-501               Mobile City & County/Baldwin County  2017
# 7      AL-504                          Montgomery City & County  2017
# 8      AL-502                        Florence/Northwest Alabama  2017
# 9      AL-506                          Tuscaloosa City & County  2017
# 10     AZ-502                     Phoenix, Mesa/Maricopa County  2017
# 11     AZ-500                          Arizona Balance of State  2017
# ...

# %% [markdown]
# ## ed_homeless_students

# %%
ed_homeless_students = master_data.dataframes['ed_homeless_students']
ed_homeless_students.head(20)
# Out:
# C:\Users\danny\AppData\Local\anaconda3\envs\dev\lib\site-packages\datadotworld\models\dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using ed_homeless_students schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 7
#   'Error: {}'.format(resource_name, e))
# C:\Users\danny\AppData\Local\anaconda3\envs\dev\lib\site-packages\datadotworld\util.py:121: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._loader_func()
#     local_education_agency_identifier school_year state_name  state_fips  \
# 0                              100005   2016-2017    Alabama           1
# 1                              100006   2016-2017    Alabama           1
# 2                              200180   2016-2017     Alaska           2
# 3                              100007   2016-2017    Alabama           1
# ...

# %% [markdown]
# ## edyouthcount

# %%
edyouthcount = master_data.dataframes['edyouthcount']
edyouthcount.head(20)
# Out:
# C:\Users\danny\AppData\Local\anaconda3\envs\dev\lib\site-packages\datadotworld\models\dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using edyouthcount schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 2
#   'Error: {}'.format(resource_name, e))
#     cocnumber  of_leas_in_coc  total_hcy_count  hotels_motels  unsheltered  \
# 0   Unmatched             271          38112.0         3190.0        860.0
# 1      AK-500               2           2476.0          166.0        168.0
# 2      AK-501              20           1642.0           63.0        240.0
# 3      AL-500              14           1938.0          134.0         21.0
# 4      AL-501               5           6159.0          156.0         63.0
# 5      AL-502              11            875.0           11.0         33.0
# 6      AL-503               8            726.0          102.0         15.0
# ...

# %% [markdown]
# ## rhy_grantees

# %%
rhy_grantees = master_data.dataframes['rhy_grantees']
rhy_grantees.head(20)
# Out:
# C:\Users\danny\AppData\Local\anaconda3\envs\dev\lib\site-packages\datadotworld\models\dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using rhy_grantees schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 9
#   'Error: {}'.format(resource_name, e))
#    coc_number                                           coc_name coc_state  \
# 0      AK-500                                      Anchorage CoC        AK
# 1      AK-500                                      Anchorage CoC        AK
# 2      AK-501                        Alaska Balance of State CoC        AK
# 3      AK-501                        Alaska Balance of State CoC        AK
# 4      AK-501                        Alaska Balance of State CoC        AK
# 5      AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...        AL
# 6      AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...        AL
# ...

# %% [markdown]
# ## ed_homeless_students_all_years

# %%
ed_homeless_students_all_years = master_data.dataframes['ed_homeless_students_all_years']
ed_homeless_students_all_years.head(20)
# Out:
# C:\Users\danny\AppData\Local\anaconda3\envs\dev\lib\site-packages\datadotworld\models\dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using ed_homeless_students_all_years schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 7
#   'Error: {}'.format(resource_name, e))
#     local_education_agency_identifier school_year state_name  state_fips  \
# 0                              100005   2016-2017    Alabama           1
# 1                              100006   2016-2017    Alabama           1
# 2                              100007   2016-2017    Alabama           1
# 3                              100008   2016-2017    Alabama           1
# 4                              100011   2016-2017    Alabama           1
# 5                              100012   2016-2017    Alabama           1
# 6                              100013   2016-2017    Alabama           1
# ...

# %% [markdown]
# #  Data PIT _Point in Time Count Data_
#    - 3 Dataframes
#     - pit_all
#     - pit_coc_codes
#     - pit_coc_categories

# %% [markdown]
# ## pit_all

# %%
pit_all = master_data.dataframes['pit_all']
pit_all.head(20)
# Out:
# C:\Users\danny\AppData\Local\anaconda3\envs\dev\lib\site-packages\datadotworld\models\dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using pit_all schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 26
#   'Error: {}'.format(resource_name, e))
#     year coc_number                                           coc_name  \
# 0   2007     AK-500                                      Anchorage CoC
# 1   2008     AK-500                                      Anchorage CoC
# 2   2007     AK-501                        Alaska Balance of State CoC
# 3   2008     AK-501                        Alaska Balance of State CoC
# 4   2007     AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 5   2008     AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 6   2007     AL-501            Mobile City & County/Baldwin County CoC
# 7   2008     AL-501            Mobile City & County/Baldwin County CoC
# ...

# %% [markdown]
# ## pit_coc_codes

# %%
pit_coc_codes = master_data.dataframes['pit_coc_codes']
pit_coc_codes.head(20)
# Out:
#     year coc_number                                          coc_name
# 0   2007     AK-500                                         Anchorage
# 1   2007     AK-501                           Alaska Balance of State
# 2   2007     AL-500  Birmingham,Jefferson, St. Clair, Shelby Counties
# 3   2007     AL-501               Mobile City & County,Baldwin County
# 4   2007     AL-502                        Florence,Northwest Alabama
# 5   2007     AL-503                          Huntsville,North Alabama
# 6   2007     AL-504                          Montgomery City & County
# 7   2007     AL-505                         Gadsden,Northeast Alabama
# 8   2007     AL-506                          Tuscaloosa City & County
# 9   2007     AL-507                          Alabama Balance of State
# 10  2007     AR-500                      Little Rock,Central Arkansas
# 11  2007     AR-501                   Fayetteville,Northwest Arkansas
# ...

# %% [markdown]
# ## pit_coc_categories

# %%
pit_coc_categories = master_data.dataframes['pit_coc_categories']
pit_coc_categories.head(20)
# Out:
#    coc_number      coc_category
# 0      AK-500  Other Urban CoCs
# 1      AK-501        Rural CoCs
# 2      AL-500     Suburban CoCs
# 3      AL-501  Other Urban CoCs
# 4      AL-502        Rural CoCs
# 5      AL-503  Other Urban CoCs
# 6      AL-504  Other Urban CoCs
# 7      AL-505        Rural CoCs
# 8      AL-506  Other Urban CoCs
# 9      AL-507        Rural CoCs
# 10     AR-500  Other Urban CoCs
# 11     AR-501  Other Urban CoCs
# 12     AR-503        Rural CoCs
# 13     AR-504        Rural CoCs
# 14     AR-505        Rural CoCs
# 15     AR-508        Rural CoCs
# 16     AZ-500        Rural CoCs
# 17     AZ-501      Major Cities
# 18     AZ-502      Major Cities
# 19     CA-500      Major Cities

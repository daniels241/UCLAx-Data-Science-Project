# %%
## Imports
import pandas as pd
import numpy as np 
import datadotworld as dw
import matplotlib.pyplot as plot
import seaborn as sns
from pathlib import Path
import sys
import os

# %%
## Change Data Path in order to Read in data from local CSVs
os.chdir(str(Path(os.getcwd()).parent / 'Data'))

# %% [markdown]
# ## spm_ard_hmis

# %%
spm_ard_hmis = pd.read_csv('spm_ard_hmis.csv')
spm_ard_hmis.head(20)
# Out:
#     year state                                           coc_name coc_number  \
# 0   2017    AK                                      Anchorage CoC     AK-500
# 1   2017    AK                        Alaska Balance of State CoC     AK-501
# 2   2017    AL  Birmingham/Jefferson, St. Clair, Shelby Counti...     AL-500
# 3   2017    AL            Mobile City & County/Baldwin County CoC     AL-501
# 4   2017    AL                     Florence/Northwest Alabama CoC     AL-502
# 5   2017    AL                       Huntsville/North Alabama CoC     AL-503
# 6   2017    AL                       Montgomery City & County CoC     AL-504
# 7   2017    AL                       Tuscaloosa City & County CoC     AL-506
# 8   2017    AL                       Alabama Balance of State CoC     AL-507
# 9   2017    AR                   Little Rock/Central Arkansas CoC     AR-500
# 10  2017    AR                Fayetteville/Northwest Arkansas CoC     AR-501
# ...

# %%
spm_ard_hmis.describe()
# Out:
#               year  spm0_coc_award_amount  \
# count  1197.000000           1.197000e+03
# mean   2015.993317           4.907325e+06
# std       0.815786           1.010057e+07
# min    2015.000000           0.000000e+00
# 25%    2015.000000           7.151120e+05
# 50%    2016.000000           1.883942e+06
# 75%    2017.000000           4.597556e+06
# max    2017.000000           1.219658e+08
#
#        spm0_total_non_dv_beds_on_hic_es_th  \
# count                          1197.000000
# mean                            908.545530
# std                            3744.306142
# min                               0.000000
# 25%                             185.000000
# 50%                             371.000000
# 75%                             785.000000
# max                           73955.000000
#
#        spm0_total_non_dv_hmis_beds_on_hic_es_th  spm1_es_sh_avg_days  \
# count                               1197.000000          1188.000000
# ...

# %%
## Check Nulls
spm_ard_hmis.isnull().apply(sum)
# Out:
# year                                                                                                           0
# state                                                                                                          0
# coc_name                                                                                                       0
# coc_number                                                                                                     0
# spm0_coc_award_amount                                                                                          0
# ahar_part_1_coc_category                                                                                       2
# spm0_total_non_dv_beds_on_hic_es_th                                                                            0
# spm0_total_non_dv_hmis_beds_on_hic_es_th                                                                       0
# ...

# %% [markdown]
# ## SPMS Only

# %%
spms_only = pd.read_csv('spm_spms_only.csv')

# %%
spms_only.describe()
# Out:
#               year  spm0_coc_award_amount  \
# count  1199.000000           1.197000e+03
# mean   2015.996664           4.907325e+06
# std       0.819211           1.010057e+07
# min    2015.000000           0.000000e+00
# 25%    2015.000000           7.151120e+05
# 50%    2016.000000           1.883942e+06
# 75%    2017.000000           4.597556e+06
# max    2018.000000           1.219658e+08
#
#        spm0_total_non_dv_beds_on_hic_es_th  \
# count                          1197.000000
# mean                            908.545530
# std                            3744.306142
# min                               0.000000
# 25%                             185.000000
# 50%                             371.000000
# 75%                             785.000000
# max                           73955.000000
#
#        spm0_total_non_dv_hmis_beds_on_hic_es_th  spm1_es_sh_avg_days  \
# count                               1197.000000          1190.000000
# ...

# %%
## Check Nulls
spms_only.isnull().apply(sum)
# Out:
# year                                                                                                           0
# state                                                                                                          0
# coc_name                                                                                                       0
# coc_number                                                                                                     0
# spm0_coc_award_amount                                                                                          2
# ahar_part_1_coc_category                                                                                       2
# spm0_total_non_dv_beds_on_hic_es_th                                                                            2
# spm0_total_non_dv_hmis_beds_on_hic_es_th                                                                       2
# ...

# %% [markdown]
# I wonder what is the difference between the spm_ard_hmi and spm_spms_only dataframe...

# %%
## Compare Funding and Coc Category Breakdown for Top 5 States by Total COC Award Amount

# %%
## top 5 States
territories = ['GU', 'VI', 'MP'] # Account for Territories
top_5 = spms_only.query("state not in {}".format(territories)).groupby('state')['spm0_coc_award_amount'].sum().sort_values(ascending=False).index[:6].tolist()

# %%
## Bottom 5 States
territories = ['GU', 'VI', 'MP'] # Account for Territories
bottom_5 = spms_only.query("state not in {}".format(territories)).groupby('state')['spm0_coc_award_amount'].sum().sort_values().index[:6].tolist()

# %%
# Graphs
sns.barplot(x='state', y ='spm0_coc_award_amount', hue='ahar_part_1_coc_category', data = spms_only.query("state in {}".format(top_5)))

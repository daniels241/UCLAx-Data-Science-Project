# %%
## Imports
import pandas as pd
import numpy as np 
import datadotworld as dw
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from IPython.display import display
import sys
import os

# %%
## Change Data Path in order to Read in data from local CSVs
os.chdir(str(Path(os.getcwd()).parent / 'Data'))

# %% [markdown]
# # System Performance Measures

# %% [markdown]
# ## spm_ard_hmis
#    - SPM = _System Performance Meausres_
#    - ARD = _Annual Reward Demand_
#    - HMIS = _Homeless Management Information System_
#    - ES = _Emergency Shelter_
#    - SH = _Save Haven_
#    - TH = _Transitional Housing_
#    - PH = _Permanent Housing_
#    - PH-RRH = _Permanent Housing-Rapid Rehousing_

# %%
spm_ard_hmis = pd.read_csv('spm_ard_hmis.csv')
spm_ard_hmis.head(20)
# Out:
#     year state                                           coc_name coc_number  \
# 0   2017    AK                                      Anchorage CoC     AK-500
# 1   2017    AK                        Alaska Balance of State CoC     AK-501
# 2   2017    AL  Birmingham/Jefferson, St. Clair, Shelby Counti...     AL-500
# 3   2017    AL            Mobile City & County/Baldwin County CoC     AL-501
# 4   2017    AL                     Florence/Northwest Alabama CoC     AL-502
# 5   2017    AL                       Huntsville/North Alabama CoC     AL-503
# 6   2017    AL                       Montgomery City & County CoC     AL-504
# 7   2017    AL                       Tuscaloosa City & County CoC     AL-506
# 8   2017    AL                       Alabama Balance of State CoC     AL-507
# 9   2017    AR                   Little Rock/Central Arkansas CoC     AR-500
# 10  2017    AR                Fayetteville/Northwest Arkansas CoC     AR-501
# ...

# %%
spm_ard_hmis.describe()
# Out:
#               year  spm0_coc_award_amount  \
# count  1197.000000           1.197000e+03
# mean   2015.993317           4.907325e+06
# std       0.815786           1.010057e+07
# min    2015.000000           0.000000e+00
# 25%    2015.000000           7.151120e+05
# 50%    2016.000000           1.883942e+06
# 75%    2017.000000           4.597556e+06
# max    2017.000000           1.219658e+08
#
#        spm0_total_non_dv_beds_on_hic_es_th  \
# count                          1197.000000
# mean                            908.545530
# std                            3744.306142
# min                               0.000000
# 25%                             185.000000
# 50%                             371.000000
# 75%                             785.000000
# max                           73955.000000
#
#        spm0_total_non_dv_hmis_beds_on_hic_es_th  spm1_es_sh_avg_days  \
# count                               1197.000000          1188.000000
# ...

# %%
## Check Nulls
sum(spm_ard_hmis.isnull().apply(sum))
# Out:
# 196

# %% [markdown]
# ## SPMS Only

# %%
spms_only = pd.read_csv('spm_spms_only.csv')

# %%
spms_only.describe()
# Out:
#               year  spm0_coc_award_amount  \
# count  1199.000000           1.197000e+03
# mean   2015.996664           4.907325e+06
# std       0.819211           1.010057e+07
# min    2015.000000           0.000000e+00
# 25%    2015.000000           7.151120e+05
# 50%    2016.000000           1.883942e+06
# 75%    2017.000000           4.597556e+06
# max    2018.000000           1.219658e+08
#
#        spm0_total_non_dv_beds_on_hic_es_th  \
# count                          1197.000000
# mean                            908.545530
# std                            3744.306142
# min                               0.000000
# 25%                             185.000000
# 50%                             371.000000
# 75%                             785.000000
# max                           73955.000000
#
#        spm0_total_non_dv_hmis_beds_on_hic_es_th  spm1_es_sh_avg_days  \
# count                               1197.000000          1190.000000
# ...

# %%
## Check Nulls
sum(spms_only.isnull().apply(sum))
# Out:
# 202

# %% [markdown]
# ## Differences Between SPM ARD HMI & SPM Only Data

# %% [markdown]
# ### Columns

# %% [markdown]
# - Year
# - State
# - Coc Name
# - Coc Number
# - Spm0 Coc Award Amount
# - Ahar Part 1 Coc Category
# - Spm0 Total Non Dv Beds On Hic Es Th
# - Spm0 Total Non Dv Hmis Beds On Hic Es Th
# - Spm1 Es Sh Avg Days
# - Spm1 Es Sh Median Days
# - Spm1 Es Sh Th Avg Days
# - Spm1 Es Sh Th Median Days
# - Spm2 Total Persons Exited So Es Th Sh Ph
# - Spm2 Total Persons Returns In 6 Mths
# - Spm2 Total Persons Returns In 12 Mths Should Include The 6 Month Cohort
# - Spm2 Total Persons Returns In 24 Mths Should Include Both The 6 And 12 Month Cohort
# - Spm3 Total Hmis Count
# - Spm4s Total Stayers Persons
# - Spm4s Total Stayers Increased Earned Income
# - Spm4s Total Stayers Increased Non Employment Cash Income
# - Spm4s Total Stayers Increased Total Income
# - Spm4l Total Leavers Persons
# - Spm4l Total Leavers Increased Earned Income
# - Spm4l Total Leavers Increased Non Employment Cash Income
# - Spm4l Total Leavers Increased Total Income
# - Spm5 Es Sh Th 1st Time Homeless
# - Spm5 Es Sh Th Ph 1st Time Homeless
# - Spm7 Total Persons Exiting Street Outreach So
# - Spm7 Total Persons Exited So To Temporary Destinations
# - Spm7 Total Persons Exited So To Permanent Destinations
# - Spm7 Total Persons Exiting Es Th Sh Ph Rrh
# - Spm7 Total Persons Exiting Es Th Sh Ph Rrh To Permanent Housing
# - Spm7 Total Persons Exiting Ph Or Remaining In Ph At End Of Reporting Period Measure Excludes Ph Rrh
# - Spm7 Total Persons Exited Ph To Permanent Destinations Or Remained In Ph For 6 Mos Measure Excludes Ph Rrh

# %% [markdown]
# Abbreviations...
# - SPM = _System Performance Meausres_
# - ARD = _Annual Reward Demand_
# - HMIS = _Homeless Management Information System_
# - HIC = _Homeless Inventory Count_
# - SO = _Street Outreach_
# - ES = _Emergency Shelter_
# - SH = _Save Haven_
# - TH = _Transitional Housing_
# - PH = _Permanent Housing_
# - PH-RRH = _Permanent Housing-Rapid Rehousing_
# - DV = _Domestic Violence_ ?

# %%
# Columns?
spms_only.columns == spm_ard_hmis.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# Looks like all columns are the same...

# %% [markdown]
# I wonder what is the difference between the spm_ard_hmi and spm_spms_only dataframe...

# %%
## Nulls?
spms_only.columns[spms_only.isnull().sum() != spm_ard_hmis.isnull().sum()]
# Out:
# Index(['spm0_coc_award_amount', 'spm0_total_non_dv_beds_on_hic_es_th',
#        'spm0_total_non_dv_hmis_beds_on_hic_es_th'],
#       dtype='object')

# %%
# Looks like COC Award Amount, Total Non DV Beds on HIC ES TH, Total Non DV HMIS Beds, on HIC ES TH have different amount of NAs

# %%
spm_ard_hmis.isnull().sum()
# Out:
# year                                                                                                           0
# state                                                                                                          0
# coc_name                                                                                                       0
# coc_number                                                                                                     0
# spm0_coc_award_amount                                                                                          0
# ahar_part_1_coc_category                                                                                       2
# spm0_total_non_dv_beds_on_hic_es_th                                                                            0
# spm0_total_non_dv_hmis_beds_on_hic_es_th                                                                       0
# ...

# %% [markdown]
# ## Processing...

# %%
## Maybe Drop NAs?
spms_only['year'].value_counts() - spms_only.dropna()['year'].value_counts()
# Out:
# 2015    9.0
# 2016    3.0
# 2017    2.0
# 2018    NaN
# Name: year, dtype: float64

# %% [markdown]
# Total of 14 entries...not a lot of data...might as well drop!

# %%
# Drop Em!
spms_only.dropna(inplace=True)

# %%
# Also rename a column for convenience
spms_only.rename(columns={'ahar_part_1_coc_category':'coc_category'}, inplace=True)

# %%
# See Categories
spms_only['coc_category'].value_counts()
# Out:
# Smaller Cities, Counties, and Regional CoCs    907
# Major Cities                                   145
# Balance of State and Statewide CoCs            130
# *                                                1
# Name: coc_category, dtype: int64

# %%
# Remove '*' entry...
spms_only = spms_only[spms_only['coc_category'] != '*'].reset_index(drop=True)

# %%
# Break Down Data by Year, might need but can also always query..
spm_2015 = spms_only.query("year == 2015").copy()
spm_2016 = spms_only.query("year == 2016").copy()
spm_2017 = spms_only.query("year == 2017").copy()

# %%
spm_2015.describe()
# Out:
#          year  spm0_coc_award_amount  spm0_total_non_dv_beds_on_hic_es_th  \
# count   392.0           3.920000e+02                           392.000000
# mean   2015.0           4.939972e+06                           951.436224
# std       0.0           1.025027e+07                          3787.192026
# min    2015.0           0.000000e+00                             0.000000
# 25%    2015.0           7.444338e+05                           201.250000
# 50%    2015.0           1.924192e+06                           408.000000
# 75%    2015.0           4.561247e+06                           816.000000
# max    2015.0           1.219658e+08                         72308.000000
#
#        spm0_total_non_dv_hmis_beds_on_hic_es_th  spm1_es_sh_avg_days  \
# count                                392.000000           392.000000
# mean                                 763.022959           227.280612
# std                                 3406.443392          2499.036552
# ...

# %% [markdown]
# ## Add DOE data

# %%
homeless_students_coc_rates = pd.read_csv('doe_homeless_students_coc_agg_rates.csv')
homeless_students_coc_rates['year'] = pd.Series([int(yr[5:]) for yr in homeless_students_coc_rates['year']])
homeless_students_coc_rates.head()
# Out:
#    year cocnumber  doe_total_rate  doe_unsheltered_rate  doe_sheltered_rate  \
# 0  2015    AK-500            62.0                 -46.0                39.0
# 1  2016    AK-500           688.0                  64.0               268.0
# 2  2017    AK-500          -429.0                  13.0              -365.0
# 3  2015    AK-501           118.0                  11.0                86.0
# 4  2016    AK-501           237.0                  33.0                16.0
#
#    doe_hotel_motel_rate  doe_doubled_up_rate
# 0                 -45.0                114.0
# 1                  12.0                344.0
# 2                 -70.0                 -7.0
# 3                 -14.0                  4.0
# 4                  37.0                164.0

# %%
for coc in homeless_students_coc_rates['cocnumber'].unique():
    if coc not in spms_only['coc_number'].unique():
        print(coc)
# Out:
# AR-504
# LA-504
# MA-518
# MA-599
# ME-502
# MO-604

# %%
## Add Doe
spms_doe_merged = spms_only.merge(homeless_students_coc_rates.rename(columns={'cocnumber':'coc_number'}), on=['coc_number', 'year'])

# %%
## Take out Entries with COC award amount = 0, doesnt make sense to get no money
sum(spms_doe_merged['spm0_coc_award_amount'] == 0)
# Out:
# 8

# %%
## Remove Values with 0 Award Amount
spms_doe_merged = spms_doe_merged[spms_doe_merged['spm0_coc_award_amount'] != 0].reset_index(drop = True).copy()

# %%
# Split Data by SPM
## Get Dict with SPM Numbers as keys and corresponding dfs as values
df_dict = {}
cols = spms_doe_merged.columns
spms = ['spm1', 'spm2', 'spm3', 'spm4', 'spm5', 'spm7']

# Keep the first few columns
spm_0 = cols[:8]
doe = cols[-5:]

## Iterate over columns
for spm in spms:
    index = list(spm_0)+list(cols[[spm in col and 'spm0' not in col for col in cols]])+list(doe)
    df_dict[spm] = spms_doe_merged[index].copy()

# %%
df_dict['spm1']
# Out:
#       year state                                           coc_name  \
# 0     2017    AK                                      Anchorage CoC
# 1     2017    AK                        Alaska Balance of State CoC
# 2     2017    AL  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 3     2017    AL            Mobile City & County/Baldwin County CoC
# 4     2017    AL                     Florence/Northwest Alabama CoC
# 5     2017    AL                       Huntsville/North Alabama CoC
# 6     2017    AL                       Montgomery City & County CoC
# 7     2017    AL                       Tuscaloosa City & County CoC
# 8     2017    AL                       Alabama Balance of State CoC
# 9     2017    AR                   Little Rock/Central Arkansas CoC
# 10    2017    AR                Fayetteville/Northwest Arkansas CoC
# 11    2017    AR                    Arkansas  Balance of State  CoC
# 12    2017    AR                             Southeast Arkansas CoC
# ...

# %% [markdown]
# ## Visualizations and Correlations

# %%
## Compare Funding and Coc Category Breakdown for Top 5 States by Total COC Award Amount

# %%
## top 5 States
territories = ['GU', 'VI', 'MP'] # Account for Territories
top_5 = spms_only.query("state not in {}".format(territories)).groupby('state')['spm0_coc_award_amount'].sum().sort_values(ascending=False).index[:6].tolist()

# %%
## Bottom 5 States
territories = ['GU', 'VI', 'MP'] # Account for Territories
bottom_5 = spms_only.query("state not in {}".format(territories)).groupby('state')['spm0_coc_award_amount'].sum().sort_values().index[:6].tolist()

# %%
# Graphs
graph = sns.barplot(x='state', y ='spm0_coc_award_amount', hue='coc_category', data = spms_only.query("state in {}".format(top_5)))
fig = graph.get_figure()
fig.savefig('graph2.png')

# %%
dir(graph)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_autotitlepos',
#  '_axes',
#  '_axes_class',
#  '_axes_locator',
#  '_axisbelow',
#  '_clipon',
#  '_clippath',
#  '_contains',
#  '_convert_dx',
#  '_current_image',
#  '_default_contains',
#  '_facecolor',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_get_axis_list',
#  '_get_axis_map',
#  '_get_clipping_extent_bbox',
#  '_get_lines',
# ...

# %% [markdown]
# ### SPM 1

# %%
spm1 = df_dict['spm1'].copy()

# %%
from IPython.display import display

stats_by_coc_cat = spm1.groupby('coc_category').describe()
for col in spm1.columns[8:]:
    print(col)
    display(stats_by_coc_cat[col].drop(columns = 'count'))
    print('\n')
# Out:
# spm1_es_sh_avg_days
#                                                   mean         std   min  \
# coc_category
# Balance of State and Statewide CoCs          73.875000   68.730452   0.0
# Major Cities                                 92.246479   85.866975  32.0
# Smaller Cities, Counties, and Regional CoCs  83.986441  303.632044  -1.0
#
#                                               25%   50%    75%     max
# coc_category
# Balance of State and Statewide CoCs          39.0  49.5   77.5   452.0
# Major Cities                                 47.0  63.0  104.0   580.0
# Smaller Cities, Counties, and Regional CoCs  38.0  56.0   82.0  8142.0
# spm1_es_sh_median_days
#                                                   mean        std  min    25%  \
# coc_category
# Balance of State and Statewide CoCs          30.775000  28.428434  0.0  17.00
# Major Cities                                 47.697183  66.997511  7.0  18.25
# ...

# %%
spm1.corr()
# Out:
#                                               year  spm0_coc_award_amount  \
# year                                      1.000000               0.004318
# spm0_coc_award_amount                     0.004318               1.000000
# spm0_total_non_dv_beds_on_hic_es_th      -0.006419               0.716106
# spm0_total_non_dv_hmis_beds_on_hic_es_th -0.003010               0.675012
# spm1_es_sh_avg_days                      -0.040027               0.028748
# spm1_es_sh_median_days                   -0.020704               0.124321
# spm1_es_sh_th_avg_days                   -0.038243               0.022157
# spm1_es_sh_th_median_days                -0.022943               0.090019
# doe_total_rate                            0.087861               0.146600
# doe_unsheltered_rate                      0.074590               0.054156
# doe_sheltered_rate                        0.011442               0.167189
# doe_hotel_motel_rate                      0.034733               0.061413
# ...

# %% [markdown]
# ### SPM 2 - See James' _Modeling_ Notebook

# %% [markdown]
# ### SPM 3

# %%
## This is just total counts...
spm3 = df_dict['spm3'].copy()

# %%
## Look at description for each column
stats_by_coc_cat = spm3.groupby('coc_category').describe()
for col in spm3.columns[8:]:
    print(col)
    display(stats_by_coc_cat[col].drop(columns = 'count'))
    print('\n')
# Out:
# spm3_total_hmis_count
#                                                      mean           std  \
# coc_category
# Balance of State and Statewide CoCs           4035.258333   3257.235951
# Major Cities                                 10136.302817  19013.835666
# Smaller Cities, Counties, and Regional CoCs   1548.953672   1543.415578
#
#                                                min      25%     50%      75%  \
# coc_category
# Balance of State and Statewide CoCs           57.0  1816.00  2999.5   5834.5
# Major Cities                                 838.0  4136.75  5995.5  10354.0
# Smaller Cities, Counties, and Regional CoCs    0.0   511.00  1124.0   1834.0
#
#                                                   max
# coc_category
# Balance of State and Statewide CoCs           12515.0
# Major Cities                                 136002.0
# Smaller Cities, Counties, and Regional CoCs    9485.0
# doe_total_rate
# ...

# %%
spm3
# Out:
#       year state                                           coc_name  \
# 0     2017    AK                                      Anchorage CoC
# 1     2017    AK                        Alaska Balance of State CoC
# 2     2017    AL  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 3     2017    AL            Mobile City & County/Baldwin County CoC
# 4     2017    AL                     Florence/Northwest Alabama CoC
# 5     2017    AL                       Huntsville/North Alabama CoC
# 6     2017    AL                       Montgomery City & County CoC
# 7     2017    AL                       Tuscaloosa City & County CoC
# 8     2017    AL                       Alabama Balance of State CoC
# 9     2017    AR                   Little Rock/Central Arkansas CoC
# 10    2017    AR                Fayetteville/Northwest Arkansas CoC
# 11    2017    AR                    Arkansas  Balance of State  CoC
# 12    2017    AR                             Southeast Arkansas CoC
# ...

# %%
## Add to Feature Set, what the hell
feature_set = spms_doe_merged[spms_doe_merged.columns[:8]].copy()
feature_set['HMIS Count'] = spm3['spm3_total_hmis_count']

# %% [markdown]
# ### SPM 4

# %%
spm4 = df_dict['spm4'].copy()

# %%
## Look at description for each column
stats_by_coc_cat = spm4.groupby('coc_category').describe()
for col in spm4.columns[8:]:
    print(col)
    display(stats_by_coc_cat[col].drop(columns = 'count'))
    print('\n')
# Out:
# spm4s_total_stayers_persons
#                                                     mean          std   min  \
# coc_category
# Balance of State and Statewide CoCs           347.950000   371.525944   4.0
# Major Cities                                 1004.500000  1232.196757  26.0
# Smaller Cities, Counties, and Regional CoCs   137.454237   190.859515   0.0
#
#                                                25%    50%     75%     max
# coc_category
# Balance of State and Statewide CoCs           77.0  200.5   482.0  1559.0
# Major Cities                                 260.0  632.5  1117.5  5923.0
# Smaller Cities, Counties, and Regional CoCs   29.0   74.0   160.0  2283.0
# spm4s_total_stayers_increased_earned_income
#                                                   mean        std  min   25%  \
# coc_category
# Balance of State and Statewide CoCs          21.500000  25.714659  0.0   3.0
# Major Cities                                 50.535211  63.618395  0.0  12.0
# ...

# %%
spm4.describe()
# Out:
#               year  spm0_coc_award_amount  \
# count  1147.000000           1.147000e+03
# mean   2015.999128           5.050401e+06
# std       0.814891           1.027163e+07
# min    2015.000000           2.490000e+03
# 25%    2015.000000           7.658745e+05
# 50%    2016.000000           1.946301e+06
# 75%    2017.000000           4.750710e+06
# max    2017.000000           1.219658e+08
#
#        spm0_total_non_dv_beds_on_hic_es_th  \
# count                          1147.000000
# mean                            936.332171
# std                            3821.786483
# min                               0.000000
# 25%                             196.000000
# 50%                             381.000000
# 75%                             812.000000
# max                           73955.000000
#
#        spm0_total_non_dv_hmis_beds_on_hic_es_th  spm4s_total_stayers_persons  \
# count                               1147.000000                  1147.000000
# ...

# %%
spm4.corr()
# Out:
#                                                         year  \
# year                                                1.000000
# spm0_coc_award_amount                               0.004318
# spm0_total_non_dv_beds_on_hic_es_th                -0.006419
# spm0_total_non_dv_hmis_beds_on_hic_es_th           -0.003010
# spm4s_total_stayers_persons                         0.005040
# spm4s_total_stayers_increased_earned_income         0.072737
# spm4s_total_stayers_increased_non_employment_ca...  0.046388
# spm4s_total_stayers_increased_total_income          0.049821
# spm4l_total_leavers_persons                        -0.010723
# spm4l_total_leavers_increased_earned_income        -0.015301
# spm4l_total_leavers_increased_non_employment_ca... -0.029103
# spm4l_total_leavers_increased_total_income         -0.027264
# doe_total_rate                                      0.087861
# doe_unsheltered_rate                                0.074590
# ...

# %%
## Can Prolly do some things with Leavers and Stayers
feature_set['SPM4 Stayers'] = spm4['spm4s_total_stayers_persons']
feature_set['SPM4 Leavers'] = spm4['spm4l_total_leavers_persons']

# %% [markdown]
# ### SPM 5

# %%
# Get dataframe..
spm5 = df_dict['spm5'].copy()

# %%
# Look into DataFrame...
spm5.describe()
# Out:
#               year  spm0_coc_award_amount  \
# count  1147.000000           1.147000e+03
# mean   2015.999128           5.050401e+06
# std       0.814891           1.027163e+07
# min    2015.000000           2.490000e+03
# 25%    2015.000000           7.658745e+05
# 50%    2016.000000           1.946301e+06
# 75%    2017.000000           4.750710e+06
# max    2017.000000           1.219658e+08
#
#        spm0_total_non_dv_beds_on_hic_es_th  \
# count                          1147.000000
# mean                            936.332171
# std                            3821.786483
# min                               0.000000
# 25%                             196.000000
# 50%                             381.000000
# 75%                             812.000000
# max                           73955.000000
#
#        spm0_total_non_dv_hmis_beds_on_hic_es_th  \
# count                               1147.000000
# mean                                 766.098518
# ...

# %% [markdown]
#  Look at California First Time Homeless vs. New York First Time Homeless

# %%
spm5[spm5['coc_number'] == 'CA-600'].sort_values(by=['year'])
# Out:
#      year state                       coc_name coc_number  \
# 808  2015    CA  Los Angeles City & County CoC     CA-600
# 424  2016    CA  Los Angeles City & County CoC     CA-600
# 41   2017    CA  Los Angeles City & County CoC     CA-600
#
#      spm0_coc_award_amount  coc_category  spm0_total_non_dv_beds_on_hic_es_th  \
# 808            100267671.0  Major Cities                              12721.0
# 424            104971653.0  Major Cities                              10982.0
# 41             108148295.0  Major Cities                              13690.0
#
#      spm0_total_non_dv_hmis_beds_on_hic_es_th  \
# 808                                    7156.0
# 424                                    6345.0
# 41                                     5052.0
#
#      spm5_es_sh_th_1st_time_homeless  spm5_es_sh_th_ph_1st_time_homeless  \
# 808                          14994.0                             20862.0
# 424                          14189.0                             22181.0
# ...

# %%
spm5[spm5['spm5_es_sh_th_ph_1st_time_homeless'] > 35000].sort_values(by=['year'])
# Out:
#       year state           coc_name coc_number  spm0_coc_award_amount  \
# 1035  2015    NY  New York City CoC     NY-600            121965844.0
# 653   2016    NY  New York City CoC     NY-600            107493608.0
# 269   2017    NY  New York City CoC     NY-600            106684572.0
#
#       coc_category  spm0_total_non_dv_beds_on_hic_es_th  \
# 1035  Major Cities                              72308.0
# 653   Major Cities                              70299.0
# 269   Major Cities                              73955.0
#
#       spm0_total_non_dv_hmis_beds_on_hic_es_th  \
# 1035                                   65813.0
# 653                                    66411.0
# 269                                    71924.0
#
#       spm5_es_sh_th_1st_time_homeless  spm5_es_sh_th_ph_1st_time_homeless  \
# 1035                          60770.0                             62145.0
# 653                           61762.0                             62981.0
# ...

# %% [markdown]
# New York has a crazy amount of Homeless People...

# %%
## Drop New York COCs and see data distribution then...
spm5_wo_ny = spm5.query("coc_number != 'NY-600'")

# %%
## Facet Grid Charts - Check Dist
g = sns.FacetGrid(spm5_wo_ny, row='coc_category', aspect=6)
g.map(sns.distplot,'spm5_es_sh_th_ph_1st_time_homeless', hist=False, rug=True)

# %% [markdown]
# Much Prettier...

# %%
g = sns.boxplot(x="year", y='spm5_es_sh_th_ph_1st_time_homeless', hue='coc_category', data=spm5_wo_ny)

# %%
## Lets Look at the Correlation Matrix
spm5.corr()
# Out:
#                                               year  spm0_coc_award_amount  \
# year                                      1.000000               0.004318
# spm0_coc_award_amount                     0.004318               1.000000
# spm0_total_non_dv_beds_on_hic_es_th      -0.006419               0.716106
# spm0_total_non_dv_hmis_beds_on_hic_es_th -0.003010               0.675012
# spm5_es_sh_th_1st_time_homeless          -0.003841               0.781662
# spm5_es_sh_th_ph_1st_time_homeless        0.000876               0.822591
# doe_total_rate                            0.087861               0.146600
# doe_unsheltered_rate                      0.074590               0.054156
# doe_sheltered_rate                        0.011442               0.167189
# doe_hotel_motel_rate                      0.034733               0.061413
# doe_doubled_up_rate                       0.095987               0.128077
#
#                                           spm0_total_non_dv_beds_on_hic_es_th  \
# ...

# %%
## Add most Relevant Features to Dataframe
feature_set['SPM5'] = spm5['spm5_es_sh_th_1st_time_homeless']

# %% [markdown]
# Looks like Award Amount and 1st Time Homeless are correlated, Visualization?

# %%
## Visualization
g = sns.FacetGrid(data=spm5.rename(columns = {'spm0_coc_award_amount':'Award Amount', 'spm5_es_sh_th_ph_1st_time_homeless':"First Time Homeless"}), aspect = 4,  col = 'coc_category', row = 'year', sharey=False, sharex=False)
g = g.map(plt.scatter, 'Award Amount','First Time Homeless')

# %% [markdown]
# ### SPM 7

# %%
spm7 = df_dict['spm7'].copy()

# %%
## Drop New York COCs and see data distribution then...
spm7_wo_ny = spm7.query("coc_number != 'NY-600'")

## Facet Grid Charts - Check Dist
g = sns.FacetGrid(spm7_wo_ny, row='coc_category', aspect=6)
g.map(sns.distplot,'spm7_total_persons_exited_so_to_temporary_destinations', hist=False, rug=True)

# %%
spm7.describe()
# Out:
#               year  spm0_coc_award_amount  \
# count  1147.000000           1.147000e+03
# mean   2015.999128           5.050401e+06
# std       0.814891           1.027163e+07
# min    2015.000000           2.490000e+03
# 25%    2015.000000           7.658745e+05
# 50%    2016.000000           1.946301e+06
# 75%    2017.000000           4.750710e+06
# max    2017.000000           1.219658e+08
#
#        spm0_total_non_dv_beds_on_hic_es_th  \
# count                          1147.000000
# mean                            936.332171
# std                            3821.786483
# min                               0.000000
# 25%                             196.000000
# 50%                             381.000000
# 75%                             812.000000
# max                           73955.000000
#
#        spm0_total_non_dv_hmis_beds_on_hic_es_th  \
# count                               1147.000000
# mean                                 766.098518
# ...

# %%
spm7.corr()
# Out:
#                                                         year  \
# year                                                1.000000
# spm0_coc_award_amount                               0.004318
# spm0_total_non_dv_beds_on_hic_es_th                -0.006419
# spm0_total_non_dv_hmis_beds_on_hic_es_th           -0.003010
# spm7_total_persons_exiting_street_outreach_so       0.044999
# spm7_total_persons_exited_so_to_temporary_desti...  0.007329
# spm7_total_persons_exited_so_to_permanent_desti...  0.057651
# spm7_total_persons_exiting_es_th_sh_ph_rrh         -0.003163
# spm7_total_persons_exiting_es_th_sh_ph_rrh_to_p... -0.005566
# spm7_total_persons_exiting_ph_or_remaining_in_p... -0.008463
# spm7_total_persons_exited_ph_to_permanent_desti... -0.004303
# doe_total_rate                                      0.087861
# doe_unsheltered_rate                                0.074590
# doe_sheltered_rate                                  0.011442
# ...

# %%
## Visualization
g = sns.FacetGrid(data=spm7.rename(columns = {'spm0_coc_award_amount':'Award Amount', 'spm7_total_persons_exited_so_to_permanent_destinations':"Exited to Permanent Housing"}), aspect = 4,  col = 'coc_category', row = 'year', sharey=False, sharex=False)
g = g.map(plt.scatter, 'Award Amount','Exited to Permanent Housing')

# %%
feature_set['SPM7'] = spm7['spm7_total_persons_exited_so_to_temporary_destinations']

# %% [markdown]
# ### Look at Feature Set Dataframe
# - SPM 5: First Time Homeless
# - SPM 7: Total People Exited to Temporary Destinations

# %%
spms_only_cleaned = pd.read_csv('spms_only_cleaned.csv')
pit_ard_data = pd.read_csv('pit_ard_merged_cleaned.csv')

# %%
spms_only_cleaned.sort_values(by = ['coc_number', 'year'], inplace = True)
spms_only_cleaned.iloc[:,7] = spms_only_cleaned.iloc[:,7] - spms_only_cleaned.iloc[:,6]
spms_only_cleaned.rename(columns = {'spm2_total_persons_returns_in_24_mths_should_include_both_the_6_and_12_month_cohort':'12_to_24_month_returns'}, inplace = True)
spms_only_cleaned.iloc[:,6] = spms_only_cleaned.iloc[:,6] - spms_only_cleaned.iloc[:,5]
spms_only_cleaned.rename(columns = {'spm2_total_persons_returns_in_12_mths_should_include_the_6_month_cohort':'6_to_12_month_returns'}, inplace = True)
spms_only_cleaned.rename(columns = {'spm2_total_persons_returns_in_6_mths':'0_to_6_month_returns'}, inplace = True)
spms_only_cleaned.rename(columns = {'spm2_total_persons_exited_so_es_th_sh_ph':'total_returns'}, inplace = True)

# %%
spm_data = spms_only_cleaned

# %%
spm_pit = pit_ard_data[['year', 'coc_number', 'coc_category']].merge(spm_data, on=['year', 'coc_number'])

# %%
spm_pit.columns
# Out:
# Index(['year', 'coc_number', 'coc_category', 'state', 'coc_name',
#        'total_returns', '0_to_6_month_returns', '6_to_12_month_returns',
#        '12_to_24_month_returns'],
#       dtype='object')

# %%
feature_set_final = feature_set.merge(spm_pit, on = ['year', 'coc_number'])

# %%
feature_set_final
# Out:
#       year state_x                                         coc_name_x  \
# 0     2017      AK                                      Anchorage CoC
# 1     2017      AK                        Alaska Balance of State CoC
# 2     2017      AL  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 3     2017      AL            Mobile City & County/Baldwin County CoC
# 4     2017      AL                     Florence/Northwest Alabama CoC
# 5     2017      AL                       Huntsville/North Alabama CoC
# 6     2017      AL                       Montgomery City & County CoC
# 7     2017      AL                       Tuscaloosa City & County CoC
# 8     2017      AL                       Alabama Balance of State CoC
# 9     2017      AR                   Little Rock/Central Arkansas CoC
# 10    2017      AR                Fayetteville/Northwest Arkansas CoC
# 11    2017      AR                    Arkansas  Balance of State  CoC
# ...

# %%
feature_set_final.columns
# Out:
# Index(['year', 'state_x', 'coc_name_x', 'coc_number', 'spm0_coc_award_amount',
#        'coc_category_x', 'spm0_total_non_dv_beds_on_hic_es_th',
#        'spm0_total_non_dv_hmis_beds_on_hic_es_th', 'HMIS Count',
#        'SPM4 Stayers', 'SPM4 Leavers', 'SPM5', 'SPM7', 'coc_category_y',
#        'state_y', 'coc_name_y', 'total_returns', '0_to_6_month_returns',
#        '6_to_12_month_returns', '12_to_24_month_returns'],
#       dtype='object')

# %%
## Add Doe
doe_spm_features = feature_set_final.merge(homeless_students_coc_rates.rename(columns={'cocnumber':'coc_number'}), on=['coc_number', 'year'])

# %%
# Drop Total Beds
doe_spm_features.drop(columns=['spm0_total_non_dv_beds_on_hic_es_th', 'spm0_total_non_dv_hmis_beds_on_hic_es_th'], inplace = True)

# %%
doe_spm_features.columns
# Out:
# Index(['year', 'state_x', 'coc_name_x', 'coc_number', 'spm0_coc_award_amount',
#        'coc_category_x', 'HMIS Count', 'SPM4 Stayers', 'SPM4 Leavers', 'SPM5',
#        'SPM7', 'coc_category_y', 'state_y', 'coc_name_y', 'total_returns',
#        '0_to_6_month_returns', '6_to_12_month_returns',
#        '12_to_24_month_returns', 'doe_total_rate', 'doe_unsheltered_rate',
#        'doe_sheltered_rate', 'doe_hotel_motel_rate', 'doe_doubled_up_rate'],
#       dtype='object')

# %%
data_final = doe_spm_features.drop(columns=['state_y', 'coc_name_y', 'coc_category_x', 'coc_name_x']).reset_index(drop=True).rename(columns= {'state_x':'State', 'year':'Year', 'coc_category_y':'coc_category'})

# %%
g = sns.pairplot(data=data_final, hue='coc_category')
# Out:
# C:\Users\danny\AppData\Local\anaconda3\envs\dev\lib\site-packages\seaborn\axisgrid.py:1342: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout(pad=layout_pad)

# %%
g = sns.boxplot(x="year", y='SPM5', hue='coc_category', data=doe_spm_features)
fig = g.get_figure()
fig.savefig('graph1.png')

# %%
doe_spm_features.columns
# Out:
# Index(['year', 'state', 'coc_name', 'coc_number', 'spm0_coc_award_amount',
#        'coc_category', 'HMIS Count', 'SPM4 Stayers', 'SPM4 Leavers', 'SPM5',
#        'SPM7', 'doe_total_rate', 'doe_unsheltered_rate', 'doe_sheltered_rate',
#        'doe_hotel_motel_rate', 'doe_doubled_up_rate'],
#       dtype='object')

# %%
g = sns.scatterplot(x = 'spm0_coc_award_amount', y = 'HMIS Count', data=doe_spm_features)
fig = g.get_figure()
fig.savefig('graph3.png')

# %%
data_final.to_csv('graph_data.csv', index=False)

# %%
data_final
# Out:
#       Year State coc_number  spm0_coc_award_amount  HMIS Count  SPM4 Stayers  \
# 0     2017    AK     AK-500              2847097.0      5236.0          76.0
# 1     2017    AK     AK-501               776502.0      2453.0          70.0
# 2     2017    AL     AL-500              9109238.0      4150.0         564.0
# 3     2017    AL     AL-501              3744586.0      2294.0         127.0
# 4     2017    AL     AL-502               447309.0         0.0          91.0
# 5     2017    AL     AL-503               650007.0       356.0          40.0
# 6     2017    AL     AL-504              1970964.0      1429.0          49.0
# 7     2017    AL     AL-506               211879.0       375.0           5.0
# 8     2017    AL     AL-507              1104980.0        75.0          42.0
# 9     2017    AR     AR-500              3107871.0      1545.0         321.0
# 10    2017    AR     AR-501               345423.0       831.0          11.0
# ...
